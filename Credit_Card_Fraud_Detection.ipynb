# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishnup211/Credit-Card-Fraud-Detection/blob/main/Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing required libraries for data analysis and visualization

# %%
import pandas as pd                       # Pandas for data manipulation and analysis
import numpy as np                        # NumPy for numerical operations
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# %%
pd.set_option('display.max_columns', None)
credit_card=pd.read_csv('/content/creditcard.csv')

# %% [markdown]
# ## Display first five rows of the loaded DataFrame

# %%
credit_card.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %% [markdown]
# ## Check if 'Unnamed: 0' column exists before deleting

# %%
if 'Unnamed: 0' in credit_card.columns:
    del credit_card["Unnamed: 0"]
    print("Column 'Unnamed: 0' deleted successfully.")
else:
    print("Column 'Unnamed: 0' not found in the DataFrame.")

# Display first two rows
credit_card.head(2)
# Out:
# Column 'Unnamed: 0' not found in the DataFrame.
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
#
#    Amount  Class
# ...

# %%
credit_card.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
credit_card.shape
# Out:
# (284807, 31)

# %%
credit_card.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# ## Data Cleaning And Trimming

# %% [markdown]
# ###  Step 1: Remove duplicate entries

# %%
credit_card = credit_card.drop_duplicates()

# %% [markdown]
# ### Step 2: Feature Engineering

# %%
credit_card['Transaction_Hour'] = (credit_card['Time'] // 3600) % 24
credit_card['Is_Night_Transaction'] = credit_card['Transaction_Hour'].apply(lambda x: 1 if x < 6 or x > 22 else 0)
credit_card['Log_Amount'] = np.log1p(credit_card['Amount'])

# %% [markdown]
# ### I have also added additional feature engineering

# %%
credit_card['Transaction_Frequency'] = credit_card.groupby('Transaction_Hour')['Transaction_Hour'].transform('count')
credit_card['Amount_Deviation'] = credit_card['Amount'] - credit_card.groupby('Transaction_Hour')['Amount'].transform('mean')

# %% [markdown]
# ### Step 3: Handle class imbalance using SMOTE

# %%
X = credit_card.drop(columns=['Class'])
y = credit_card['Class']

# %%
smote = SMOTE(sampling_strategy=0.5, random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %% [markdown]
# ### Step 4: Standardize the 'Amount' column

# %%
scaler = StandardScaler()
X_resampled[['Amount', 'Amount_Deviation']] = scaler.fit_transform(X_resampled[['Amount', 'Amount_Deviation']])

# %% [markdown]
# ### Step 4: Split the data into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled)

# %% [markdown]
# ### Step 5: Train a classification model

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# ###  Step 6: Model Evaluation

# %%
y_pred = clf.predict(X_test)
y_pred_prob = clf.predict_proba(X_test)[:, 1]

# %% [markdown]
# ### The Final Output will be

# %%
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("ROC-AUC Score:", roc_auc_score(y_test, y_pred_prob))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56651
#            1       1.00      1.00      1.00     28325
#
#     accuracy                           1.00     84976
#    macro avg       1.00      1.00      1.00     84976
# weighted avg       1.00      1.00      1.00     84976
#
# Confusion Matrix:
# [[56645     6]
#  [    1 28324]]
# ROC-AUC Score: 0.9999889336519697
